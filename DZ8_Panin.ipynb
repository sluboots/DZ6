# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Maksim\Desktop\datasets\TelecomChurn.csv')

# %%
df # Данный датасет представлен в широкой форме
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      LA             117        408                 No              No
# 1      IN              65        415                 No              No
# 2      NY             161        415                 No              No
# 3      SC             111        415                 No              No
# 4      HI              49        510                 No              No
# ..    ...             ...        ...                ...             ...
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['State'].unique()
# Out:
# array(['LA', 'IN', 'NY', 'SC', 'HI', 'AK', 'MI', 'ID', 'VA', 'WI', 'MN',
#        'VT', 'MT', 'MA', 'KY', 'CO', 'AZ', 'CA', 'WA', 'NE', 'OH', 'MO',
#        'AL', 'NH', 'NM', 'OR', 'TX', 'MS', 'WY', 'FL', 'KS', 'NC', 'SD',
#        'OK', 'CT', 'RI', 'DE', 'UT', 'NV', 'DC', 'ME', 'IL', 'NJ', 'MD',
#        'WV', 'PA', 'ND', 'AR', 'TN', 'IA', 'GA'], dtype=object)

# %%
long_df = df[['State', 'Account length', 'Total day minutes', 'Total day calls']]
long_df = long_df[(long_df['State'] == 'LA')|(long_df['State'] == 'IN')]
long_df.set_index(['State', 'Account length'], drop=True, inplace=True)

# %%
long_df # Процесс прдеставления данных из широкой в длинную
# Out:
#                       Total day minutes  Total day calls
# State Account length
# LA    117                         184.5               97
# IN    65                          129.1              137
# LA    155                         203.4              100
#       121                         181.5              121
# IN    122                         243.8               98
# LA    99                          241.1               72
# IN    65                          213.4              111
#       122                         296.4               99
# LA    149                         198.9               77
# IN    78                          208.9              119
# LA    67                          310.4               97
#       172                         215.7              140
#       43                          241.9              101
#       108                         276.6               99
# IN    100                         216.2              107
# ...

# %%
table = pd.pivot_table(df, values="Total day minutes", index=['State', 'Account length'], aggfunc='sum')

# %%
table # В данной таблице, представлена общая сумма звонков у пользователся. Данный отсортированы по Штату проживания и длины аккаунта(?)
# Out:
#                       Total day minutes
# State Account length
# AK    1                           175.2
#       36                          146.3
#       55                          139.3
#       76                          160.1
#       96                          150.0
# ...                                 ...
# WY    127                         247.5
#       134                         296.0
#       146                         180.7
#       148                         243.0
#       215                          83.6
#
# [636 rows x 1 columns]

# %%
long_df.groupby('Total day calls').agg('min') # В данной таблице представлено общее количество звонков произведенные днём и минимальное количество минут
# Out:
#                  Total day minutes
# Total day calls
# 72                           241.1
# 77                           198.9
# 82                           209.2
# 84                           141.1
# 85                           203.8
# 92                           141.1
# 97                           113.8
# 98                           243.8
# 99                           276.6
# 100                          203.4
# 101                          241.9
# 102                          191.4
# 104                          128.8
# 107                          216.2
# 111                          213.4
# 116                          145.1
# 119                          208.9
# 120                          115.9
# 121                          181.5
# 123                          125.2
# 124                          168.3
# 127                          116.9
# 128                          190.5
# 129                          115.6
# 137                          129.1
# ...
